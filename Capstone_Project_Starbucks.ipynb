# %% [markdown]
# <a href="https://colab.research.google.com/github/Sweetpea007/Projects/blob/main/Capstone_Project_Starbucks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from matplotlib import style
import seaborn as sns

# %%
#imported data
df = pd.read_csv('https://raw.githubusercontent.com/Sweetpea007/Projects/main/starbucks-.csv')

# %%
#data preview 1
df.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
#data preview 2
df.tail()
# Out:
#            Brand  Store Number      Store Name Ownership Type  \
# 25595  Starbucks  21401-212072             Rex       Licensed
# 25596  Starbucks  24010-226985        Panorama       Licensed
# 25597  Starbucks  47608-253804   Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809    Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286  Mall of Africa       Licensed
#
#                                           Street Address  \
# 25595  141 Nguyễn Huệ, Quận 1, Góc đường Pasteur và L...
# 25596  SN-44, Tòa Nhà Panorama, 208 Trần Văn Trà, Quận 7
# 25597          Cnr Tyrwhitt and Cradock Avenue, Rosebank
# 25598  Shop 61B, Central Square, Cnr Aramist & Coroba...
# 25599             Shop 2077, Upper Level, Waterfall City
#
#                         City State/Province Country Postcode  Phone Number  \
# 25595  Thành Phố Hồ Chí Minh             SG      VN    70000  08 3824 4668
# 25596  Thành Phố Hồ Chí Minh             SG      VN    70000  08 5413 8292
# ...

# %%
#Data types
df.dtypes
# Out:
# Brand              object
# Store Number       object
# Store Name         object
# Ownership Type     object
# Street Address     object
# City               object
# State/Province     object
# Country            object
# Postcode           object
# Phone Number       object
# Timezone           object
# Longitude         float64
# Latitude          float64
# dtype: object

# %%
#confirming if data is missing
df.isnull().sum()
# Out:
# Brand                0
# Store Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                15
# State/Province       0
# Country              0
# Postcode          1522
# Phone Number      6861
# Timezone             0
# Longitude            1
# Latitude             1
# dtype: int64

# %%
# of rows and columns
df.shape
# Out:
# (25600, 13)

# %%
# How many Starbucks locations worldwide?
df.shape [0]
# Out:
# 25600

# %% [markdown]
# **25,599 Starbucks locations since data rows include header row

# %%
# column names
df.columns
# Out:
# Index(['Brand', 'Store Number', 'Store Name', 'Ownership Type',
#        'Street Address', 'City', 'State/Province', 'Country', 'Postcode',
#        'Phone Number', 'Timezone', 'Longitude', 'Latitude'],
#       dtype='object')

# %%
#How many counrties have startbuck locationa?
len(df.Country.unique())
# Out:
# 73

# %%
#What region has the most Starbucks locations?
df.Country.value_counts().head(1)
# Out:
# US    13608
# Name: Country, dtype: int64

# %%
#What are the top 10 countries with Starbucks locaions?
df.Country.value_counts().head(10)
# Out:
# US    13608
# CN     2734
# CA     1468
# JP     1237
# KR      993
# GB      901
# MX      579
# TW      394
# TR      326
# PH      298
# Name: Country, dtype: int64

# %%
#How many Starbucks locaions in New York?

df[df['State/Province']=='NY']
# Out:
#            Brand  Store Number                        Store Name  \
# 20858  Starbucks     7379-1056                         Wolf Road
# 20859  Starbucks  11064-103915                   Crossgates Mall
# 20860  Starbucks  15207-156777             Target Colonie T-1268
# 20861  Starbucks    7922-92120                North Pearl Street
# 20862  Starbucks  75393-105057                  College St. Rose
# ...          ...           ...                               ...
# 21498    Teavana  28235-250120  Teavana - Westchester Ridge HIll
# 21499  Starbucks  13632-105641      Cross County Shopping Center
# 21500  Starbucks  14369-115444         Yonkers, Bronx River Road
# 21501  Starbucks    7901-67260                           Yonkers
# 21502  Starbucks     7504-7590                          Yorktown
#
#       Ownership Type                                     Street Address  \
# 20858  Company Owned                        18 Wolf Rd, Crossgates Mall
# ...

# %%
#How many Starbucks locaions in New York City?

df[df['City']=='New York']
# Out:
# Object `CIty` not found.
#            Brand  Store Number                 Store Name Ownership Type  \
# 21129  Starbucks    818-227125              80th & Second  Company Owned
# 21130  Starbucks  14318-119964            Nassau & Fulton  Company Owned
# 21131  Starbucks    7670-36979                 49th & 8th  Company Owned
# 21132  Starbucks    7626-33939          Spring and Varick  Company Owned
# 21133  Starbucks    7699-45959            95th & Broadway  Company Owned
# ...          ...           ...                        ...            ...
# 21356  Starbucks     7456-3949              125th & Lenox  Company Owned
# 21357  Starbucks  75491-113947         Limited Brands-NYC       Licensed
# 21358  Starbucks     7393-1367        49th btwn 8th & 9th  Company Owned
# 21359  Starbucks     7285-1073                 22nd & 6th  Company Owned
# 21360  Starbucks     7444-3689  Rockefeller Center Subway  Company Owned
#
# ...

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
ax.set(title = "Top 10 Countries with Starbucks locations")
df.Country.value_counts().head(10).plot(kind="bar", color = "blue")

# %%
#What are the types of ownership?
df['Ownership Type'].value_counts()
# Out:
# Company Owned    11932
# Licensed          9375
# Joint Venture     3976
# Franchise          317
# Name: Ownership Type, dtype: int64

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
ax.set(title = "What are the types of ownership?")
df['Ownership Type'].value_counts().plot(kind="bar", color = "red")
plt.show()

# %%
#Drop phone number column since some data is missing 
df.drop('Phone Number', axis=1, inplace=True)

# %%
#data preview to confirm Phone Number column was dropped 
df.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode                 Timezone  Longitude  Latitude
# 0    AD500  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %% [markdown]
# **Conclusion**
# 1. How many Starbucks loactions are there worldwide?
#
# Based on my analyst, there are 25,599 starbucks locations worldwide.
#
# 2. What region has the most Starbucks locations?
#
# The region with the most Starbucks locations is the United States with New York City having the most locations.
#
# 3. What are the types of ownership?
#
# The types of ownerships are company owned, joint ventures, licensed and franchise.
